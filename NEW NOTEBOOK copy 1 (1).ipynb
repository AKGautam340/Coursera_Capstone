# %% [markdown]
# # COURSERA CAPSTONE PROJECT
# THIS NOTEBOOK WOULD BE USED FOR FINAL CAPSTONE PROJECT OF CORCERA DATA SCIENCE CERTIFICATION

# %%
import pandas as pd
import numpy as np
print("Hello Coursera Course !")
# Out:
# Hello Coursera Course !
